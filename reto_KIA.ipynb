# %%
# Importamos las librerias

# !pip install pyqrcode pypng

import pyqrcode
import png
from pyqrcode import QRCode

# %%
# CODIGOS QR ID
# Variables
con = 5678

# %%
# Generamos los QR
while con <= 9999:

    #id = str('j') +  str(con)
    roster = con
    id = '65' + str(con)
    # Creamos los QR
    qr = pyqrcode.create(65 and id, error= 'L')
    # Guardamos
    qr.png('A' + str(roster) + '.png', scale = 6)
    # Aumentamos con
    con = con + 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 10
#       8 qr = pyqrcode.create(65 and id, error= 'L')
#       9 # Guardamos
# ---> 10 qr.png('A' + str(roster) + '.png', scale = 6)
#      11 # Aumentamos con
#      12 con = con + 1
#
# File c:\Users\Aze_g\Downloads\anaconda\Lib\site-packages\pyqrcode\__init__.py:462, in QRCode.png(self, file, scale, module_color, background, quiet_zone)
#     416 def png(self, file, scale=1, module_color=(0, 0, 0, 255),
#     417         background=(255, 255, 255, 255), quiet_zone=4):
#     418     """This method writes the QR code out as an PNG image. The resulting
#     419     PNG has a bit depth of 1. The file parameter is used to specify where
#     420     to write the image to. It can either be an writable stream or a
#    (...)
#     460                      background=(0xff, 0xff, 0xff, 0x88)) #50% transparent white
# ...

# %%
# Importamos librerias para lecturas
# !apt-get install libzbar0
# !pip install pyzbar
# !pip install opencv-python

import cv2
import pyqrcode
import png
from pyqrcode import QRCode
from pyzbar.pyzbar import decode
import numpy as np
# Out:
# "apt-get" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# ...

# %%
# Creamos la videocaptura
cap = cv2.VideoCapture(0)

# %%
# Empezamos
while True:
    # Leemos los frames
    ret, frame = cap.read()

    # Leemos los codigos QR
    for codes in decode(frame):
        # Extraemos info
        #info = codes.data

        # Decodidficamos
        info = codes.data.decode('utf-8')

        # Tipo de persona LETRA
        tipo = info[0:2]
        tipo = int(tipo)

        # Extraemos coordenadas
        pts = np.array([codes.polygon], np.int32)
        xi, yi = codes.rect.left, codes.rect.top

        # Redimensionamos
        pts = pts.reshape((-1,1,2))

        if tipo == 69:  # J->74 # E->69
            # Dibujamos
            cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
            cv2.putText(frame, 'E0' + str(info[2:]), (xi - 15, yi - 15), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 55, 0), 2)
            print(" El usuario es accionista de la empresa  \n"
                  " Numero de Identificacion: E", str(info[2:]))

        if tipo == 71:  # F->70 # G->71
            # Dibujamos
            cv2.polylines(frame, [pts], True, (255, 0, 255), 5)
            cv2.putText(frame, 'G0' + str(info[2:]), (xi - 15, yi - 15), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)
            print(" El usuario pertenece a la seccion ejecutiva \n"
                  " Numero de Identificacion: G", str(info[2:]))

        if tipo == 83:  # C->99 # S->83
            # Dibujamos
            cv2.polylines(frame, [pts], True, (0, 255, 255), 5)
            cv2.putText(frame, 'S0' + str(info[2:]), (xi - 15, yi - 15), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
            print(" El usuario pertenece a la seccion salud \n"
                  " Numero de Identificacion: S", str(info[2:]))

        if tipo == 65:  # C->99 # S->83
            # Dibujamos
            cv2.polylines(frame, [pts], True, (0, 255, 255), 5)
            cv2.putText(frame, 'A0' + str(info[2:]), (xi - 15, yi - 15), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
            print(" Numero de Identificacion: A", str(info[2:]))
        # Imprimimos
        print(info)

    # Mostramos FPS
    cv2.imshow(" LECTOR DE QR", frame)
    # Leemos teclado
    t = cv2.waitKey(5)
    if t == 27:
        break
# Out:
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
#  Numero de Identificacion: A 1234
# 651234
# ...

# %%
cv2.destroyAllWindows()
cap.release()

# %%
#Librerias para lectura
import cv2
from pyzbar.pyzbar import decode
import numpy as np
from datetime import datetime 
import openpyxl as xl

# %%
#Videocaptura
cap = cv2.VideoCapture(0)

# %%
#Variables
mañana = []
tarde = []
noche = []

# %%
#Horario
def infhora():
    #información 
    inf= datetime.now()
    #Se extrae fecha
    fecha = inf.strftime('%y:%m:%d')
    #Se extrae hora
    hora = inf.strftime('%H:%M:%S')
    return hora, fecha

# %%
#Principal
while True:
    #Lectura de frames
    ret, frame = cap.read()
    
    #interfaz
    cv2.putText(frame, 'Coloca el código QR', (160,80), cv2.FONT_HERSHEY_SIMPLEX, 1,(0,255,0),2)
    #uBICACIÓN DE RECTANGULO
    cv2.rectangle(frame, (170,100),(470,400),(0,255,0),2)
    #Se extrae hora y fecha
    hora, fecha =infhora()
    diasem= datetime.today().weekday()
    
    print(diasem)
    #año, mes, dia
    a, me, d = fecha[0:4], fecha[5:7], fecha[8:10]
    #hora, minuto, segundo
    h, m, s = int(hora[0:2]), int(hora[3:5]), int(hora[6:8])
    
    #Se crea archivo
    nomar = str(a) + '-' + str(me) + '-' + str(d)
    texth = str(h) + '-' + str(m) + '-' + str(s)
    print(texth)
    wb= xl.Workbook()
    
    #Lectura de codigos
    for codes in decode(frame):
        info= codes.data.decode('utf-8')
        #tipo de persona
        tipo = info [0:2]
        tipo = int (tipo)
        letr = chr(tipo)
        #número
        num = info[2:]
        
        #extraemos coordenadas
        pts = np.array([codes.polygon], np.int32)
        xi, yi, = codes.rect.left, codes.rect.top
        
        #rediemnsionamos
        pts = letr + num
        
        #dia de la sem
        if 4 >= diasem >=0:
            #se divide las horas del dia
            #mañana
            if 10 >= h >= 7:
                cv2.polylines(frame,[pts], True, (255,255,0), 5)
                #se guarda id
                if codigo not in mañana:
                    #agregamos id
                    pos = len(mañana)
                    mañana.append(codigo)
                    
                    #guardamos db
                    hojan = wb.create_sheet("Mañana")
                    datos = hojan.append(mañana)
                    wb.save(nomar+'.xlsx')
                    
                elif codigo in mañana:
                    cv2.putText(frame,'El ID'+ str(codigo),
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.putText(frame,'Fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            #tarde
            if 14 >= h >=11:
                cv2.polylines(frame,[pts], True, (255,255,0), 5)
                #se guarda id
                if codigo not in tarde:
                    #agregamos id
                    tarde.append(codigo)   
                    cv2.putText(frame, letr+'0'+str(num),(xi-15,yi-15),cv2.FONT_HERSHEY_SIMPLEX, 1, (255,55,0), 2) #CREO QUE FALTA AQUI
                    
                    #Guardamos db
                    hojat= wb.create_sheet("Tarde")
                    datos = hojat.append(tarde)
                    wb.save(nomar+'.xlsx')
                #Aviso
                elif codigo in tarde:
                    cv2.putText(frame, 'El ID'+str(codigo),
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.putText(frame, 'Fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                print(tarde)
                    
            
            #noche
            if 20 >= h >= 17:
                cv2.polylines(frame,[pts], True, (255,255,0), 5)
                #se guarda id
                if codigo not in noche:
                    #agregamos id
                    noche.append(codigo)
                    cv2.putText(frame, letr+'0'+str(num),(xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 55, 8), 2)
                    
                     #Guardamos db
                    hojan= wb.create_sheet("Noche")
                    datos = hojan.append(noche)
                    wb.save(nomar+'.xlsx')
               
                #Aviso
                elif codigo in noche:
                    cv2.putText(frame, 'El ID'+str(codigo),
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                    cv2.putText(frame, 'Fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0,255), 2)
                print(noche)
#Dias de la sem

if 6 >= diasem >=5:
    #Divicion de las horas
    #mañana
    if 8 >= h >=6:
        cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
        #guardamos id 
        if codigo not in mañana:
            #agregamos id
            mañana.append(codigo)
            cv2.putText(frame, letr+'0'+str(num), (xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 55, 0), 2)
            
            #guardar db
            hojam= wb.create_sheet("Mañana")
            datos= hojam.append(mañana)
            wb.save(nomar+'xlsx')
        #avisamos
        elif codigo in mañana:
            cv2.putText(frame,'El ID'+ str(codigo),
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
            cv2.putText(frame,'Fue registrado',
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        print(mañana)
    
    #tarde
    if h==11 and m>=30:
        cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
        #guardamos id 
        if codigo not in tarde:
            #agregamos id
            tarde.append(codigo)
            cv2.putText(frame, letr+'0'+str(num), (xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 55, 0), 2)
            
            #guardar db
            hojat= wb.create_sheet("Tarde")
            datos= hojat.append(tarde)
            wb.save(nomar+'xlsx')
            
        #avisamos
        elif codigo in tarde:
            cv2.putText(frame,'El roster'+ str(codigo),
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame,'Fue registrado',
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    elif 13 >= h >= 11:
        cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
        #guardamos id 
        if codigo not in tarde:
            #agregamos id
            tarde.append(codigo)
            cv2.putText(frame, letr+'0'+str(num), (xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 55, 0), 2)
            
            #guardar db
            #hojat= wb.create_sheet("Tarde")
            datos= hojat.append(tarde)
            wb.save(nomar+'xlsx')
            
            #avisamos
        elif codigo in tarde:
            cv2.putText(frame,'El roster'+ str(codigo),
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame,'Fue registrado',
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    
    
    elif h == 13 and  m <= 30:
        cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
        #guardamos id 
        if codigo not in tarde:
            #agregamos id
            tarde.append(codigo)
            cv2.putText(frame, letr+'0'+str(num), (xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 55, 0), 2)
            
            #guardar db
            #hojat= wb.create_sheet("Tarde")
            datos= hojat.append(tarde)
            wb.save(nomar+'xlsx')
            
            #avisamos
        elif codigo in tarde:
            cv2.putText(frame,'El roster'+ str(codigo),
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(frame,'Fue registrado',
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            
        
    #Noche
    if 19 >= h >= 17:
        cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
        #guardamos id 
        if codigo not in noche:
            #agregamos id
            noche.append(codigo)
            cv2.putText(frame, letr+'0'+str(num), (xi-15, yi-15), cv2.FONT_HERSHEY_SIMPLEX, 1,
                        (255, 55, 0), 2)
            
            #guardar db
            hojan= wb.create_sheet("Noche")
            datos= hojan.append(noche)
            wb.save(nomar+'xlsx')
            
        #avisamos
        elif codigo in noche:
            cv2.putText(frame,'El roster'+ str(codigo),
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            cv2.putText(frame,'Fue registrado',
                        (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        print(mañana)
        
#Mostramos FPS
cv2.imshow("QR READER", frame)

#Leemos teclado
t= cv2.waitKey(5)
if t==27:
    break
cv2.destroyAllWindows()
cap.release()
# Out:
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-35
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-36
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# 9-52-37
# 2
# ...

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#CODIGO OFICIAL 
#  Librerías para lectura
import cv2
from pyzbar.pyzbar import decode
import numpy as np
from datetime import datetime 
import openpyxl as xl

# Videocaptura
cap = cv2.VideoCapture(0)

# Variables
mañana = []
tarde = []
noche = []

# Horario
def infhora():
    # información 
    inf = datetime.now()
    # Se extrae fecha
    fecha = inf.strftime('%Y-%m-%d')
    # Se extrae hora
    hora = inf.strftime('%H-%M-%S')
    return hora, fecha

# Crear libro de Excel al inicio
wb = xl.Workbook()
sheet_names = ["Mañana", "Tarde", "Noche"]
for name in sheet_names:
    wb.create_sheet(name)

while True:
    # Lectura de frames
    ret, frame = cap.read()
    
    if not ret:
        print("No se puede capturar el frame de la cámara")
        break

    # Interfaz
    cv2.putText(frame, 'Coloca el codigo QR', (160, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.rectangle(frame, (170, 100), (470, 400), (0, 255, 0), 2)
    
    # Se extrae hora y fecha
    hora, fecha = infhora()
    diasem = datetime.today().weekday()
    
    # Año, mes, día
    a, me, d = fecha.split('-')
    # Hora, minuto, segundo
    h, m, s = hora.split('-')
    
    # Nombre para el archivo
    nomar = f"{a}-{me}-{d}"

    # Lectura de códigos
    for codes in decode(frame):
        info = codes.data.decode('utf-8')
        codigo = info  # Asignamos el código leído
        # Tipo de persona
        tipo = info[0:2]
        tipo = int(tipo)
        letr = chr(tipo)
        # Número
        num = info[2:]
        
        # Extraemos coordenadas
        pts = np.array([codes.polygon], np.int32)
        pts = pts.reshape((-1, 1, 2))
        xi, yi = codes.rect.left, codes.rect.top
        
        # Dividimos el día y hora en franjas
        if 4 >= diasem >= 0:  # Días laborables
            if 10 >= int(h) >= 7:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in mañana:
                    mañana.append(codigo)
                    wb["Mañana"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 14 >= int(h) >= 11:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in tarde:
                    tarde.append(codigo)
                    wb["Tarde"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 20 >= int(h) >= 17:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in noche:
                    noche.append(codigo)
                    wb["Noche"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Mostramos FPS
    cv2.imshow("QR READER", frame)
    
    # Leemos teclado
    t = cv2.waitKey(1)
    if t == 27:  # ESC key to exit
        break

# Liberamos recursos
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 34
#      30     wb.create_sheet(name)
#      32 while True:
#      33     # Lectura de frames
# ---> 34     ret, frame = cap.read()
#      36     if not ret:
#      37         print("No se puede capturar el frame de la cámara")
#
# KeyboardInterrupt:

# %%
cv2.destroyAllWindows()
cap.release()

# %%
#CODIGO INTEGRANDO POSTGRESQL 
#  Librerías para lectura

import streamlit as st
import pandas as pd 
import numpy as np
import asqlalchemy as sa
import psycopg2
import cv2
from pyzbar.pyzbar import decode
import numpy as np
from datetime import datetime 
import openpyxl as xl
from sqlalchemy. engine import URL

#Conexión base de datos
#conString = 'postgresql+psycopg2://[postgres]:[KxVsYrSSmUy6424M]@db.rucchmdwalvfpsmdjawg.supabase.co:5432/postgres
conString = 'postgresql+psycopg2://postgresql://postgres:[KxVsYrSSmUy6424M]@db.rucchmdwalvfpsmdjawg.supabase.co:5432/postgres


# Videocaptura
cap = cv2.VideoCapture(0)

# Variables
mañana = []
tarde = []
noche = []

# Horario
def infhora():
    # información 
    inf = datetime.now()
    # Se extrae fecha
    fecha = inf.strftime('%Y-%m-%d')
    # Se extrae hora
    hora = inf.strftime('%H-%M-%S')
    return hora, fecha

# Crear libro de Excel al inicio
wb = xl.Workbook()
sheet_names = ["Mañana", "Tarde", "Noche"]
for name in sheet_names:
    wb.create_sheet(name)

while True:
    # Lectura de frames
    ret, frame = cap.read()
    
    if not ret:
        print("No se puede capturar el frame de la cámara")
        break

    # Interfaz
    cv2.putText(frame, 'Coloca el codigo QR', (160, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.rectangle(frame, (170, 100), (470, 400), (0, 255, 0), 2)
    
    # Se extrae hora y fecha
    hora, fecha = infhora()
    diasem = datetime.today().weekday()
    
    # Año, mes, día
    a, me, d = fecha.split('-')
    # Hora, minuto, segundo
    h, m, s = hora.split('-')
    
    # Nombre para el archivo
    nomar = f"{a}-{me}-{d}"

    # Lectura de códigos
    for codes in decode(frame):
        info = codes.data.decode('utf-8')
        codigo = info  # Asignamos el código leído
        # Tipo de persona
        tipo = info[0:2]
        tipo = int(tipo)
        letr = chr(tipo)
        # Número
        num = info[2:]
        
        # Extraemos coordenadas
        pts = np.array([codes.polygon], np.int32)
        pts = pts.reshape((-1, 1, 2))
        xi, yi = codes.rect.left, codes.rect.top
        
        # Dividimos el día y hora en franjas
        if 4 >= diasem >= 0:  # Días laborables
            if 10 >= int(h) >= 7:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in mañana:
                    mañana.append(codigo)
                    wb["Mañana"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 14 >= int(h) >= 11:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in tarde:
                    tarde.append(codigo)
                    wb["Tarde"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 20 >= int(h) >= 17:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in noche:
                    noche.append(codigo)
                    wb["Noche"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Mostramos FPS
    cv2.imshow("QR READER", frame)
    
    # Leemos teclado
    t = cv2.waitKey(1)
    if t == 27:  # ESC key to exit
        break

# Liberamos recursos
cap.release()
cv2.destroyAllWindows()

# %%
# Librerías para lectura
import cv2
from pyzbar.pyzbar import decode
import numpy as np
from datetime import datetime 
import openpyxl as xl
from supabase import create_client, Client

# Videocaptura
cap = cv2.VideoCapture(0)

# Variables
mañana = []
tarde = []
noche = []

# Inicializar Supabase
url = "xxx"
api_key = "xxx"
supabase: Client = create_client(url, api_key)

# Horario
def infhora():
    # información 
    inf = datetime.now()
    # Se extrae fecha
    fecha = inf.strftime('%Y-%m-%d')
    # Se extrae hora
    hora = inf.strftime('%H-%M-%S')
    return hora, fecha

# Crear libro de Excel al inicio
wb = xl.Workbook()
sheet_names = ["Mañana", "Tarde", "Noche"]
for name in sheet_names:
    wb.create_sheet(name)

while True:
    # Lectura de frames
    ret, frame = cap.read()
    
    if not ret:
        print("No se puede capturar el frame de la cámara")
        break

    # Interfaz
    cv2.putText(frame, 'Coloca el codigo QR', (160, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    cv2.rectangle(frame, (170, 100), (470, 400), (0, 255, 0), 2)
    
    # Se extrae hora y fecha
    hora, fecha = infhora()
    diasem = datetime.today().weekday()
    
    # Año, mes, día
    a, me, d = fecha.split('-')
    # Hora, minuto, segundo
    h, m, s = hora.split('-')
    
    # Nombre para el archivo
    nomar = f"{a}-{me}-{d}"

    # Lectura de códigos
    for codes in decode(frame):
        info = codes.data.decode('utf-8')
        codigo = info  # Asignamos el código leído
        # Tipo de persona
        tipo = info[0:2]
        tipo = int(tipo)
        letr = chr(tipo)
        # Número
        num = info[2:]
        
        # Extraemos coordenadas
        pts = np.array([codes.polygon], np.int32)
        pts = pts.reshape((-1, 1, 2))
        xi, yi = codes.rect.left, codes.rect.top
        
        # Dividimos el día y hora en franjas
        if 4 >= diasem >= 0:  # Días laborables
            if 10 >= int(h) >= 7:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in mañana:
                    mañana.append(codigo)
                    wb["Mañana"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 14 >= int(h) >= 11:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in tarde:
                    tarde.append(codigo)
                    wb["Tarde"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    
            elif 20 >= int(h) >= 17:
                cv2.polylines(frame, [pts], True, (255, 255, 0), 5)
                if codigo not in noche:
                    noche.append(codigo)
                    wb["Noche"].append([codigo])
                    wb.save(nomar + '-' + hora + '.xlsx')
                else:
                    cv2.putText(frame, 'El ID ' + str(codigo) + ' fue registrado',
                                (xi-65, yi-45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Mostramos FPS
    cv2.imshow("QR READER", frame)
    
    # Leemos teclado
    t = cv2.waitKey(1)
    if t == 27:  # ESC key to exit
        break

# Liberamos recursos
cap.release()
cv2.destroyAllWindows()
# Out:
#   Cell In[7], line 122
#     break
#     ^
# SyntaxError: 'break' outside loop
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install supabase
# !pip install opencv-python
# !pip install pyzbar
import cv2
from pyzbar.pyzbar import decode
from supabase import create_client, Client
from datetime import datetime

# Configurar Supabase
url: str = "https://rucchmdwalvfpsmdjawg.supabase.co"
key: str = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InJ1Y2NobWR3YWx2ZnBzbWRqYXdnIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjUwMzU1NDgsImV4cCI6MjA0MDYxMTU0OH0.qkaWcGeR-KqLe_UJS0uYfoPjxFfQXTLNB80vrGg_Tv0"
supabase: Client = create_client(url, key)

# Configurar la videocaptura
cap = cv2.VideoCapture(0)

# Variable para identificar el estacionamiento
estacionamiento = "Estacionamiento 1"  # Cambia este valor según el estacionamiento

# Función para obtener la hora y fecha actual
def infhora():
    inf = datetime.now()
    fecha = inf.strftime('%Y-%m-%d')
    hora = inf.strftime('%H-%M-%S')
    return hora, fecha

# Ciclo principal de lectura de QR
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("No se puede capturar el frame de la cámara")
        break

    for codes in decode(frame):
        codigo = codes.data.decode('utf-8')
        
        # Verificar si el código ya existe en la base de datos
        response = supabase.table("tu_tabla").select("*").eq("codigo_qr", codigo).execute()
        registros = response.data
        
        if len(registros) == 0:
            # Si no existe, insertar un nuevo registro
            supabase.table("tu_tabla").insert({
                "codigo_qr": codigo,
                "Estacionamiento": estacionamiento,
                "fecha_registro": datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            }).execute()
            print(f"Nuevo código registrado en {estacionamiento}: {codigo}")
        else:
            # Si existe, comprobar si ya está en el mismo estacionamiento
            registro = registros[0]
            if registro["Estacionamiento"] != estacionamiento:
                print(f"El código {codigo} ya está registrado en {registro['Estacionamiento']}")

    # Salir del ciclo si se presiona la tecla ESC
    if cv2.waitKey(1) == 27:  # ESC para salir
        break

# Liberar recursos
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
#    ---------------------------------------- 0.0/47.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/47.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/47.5 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.5 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.5 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.5 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.5 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/47.5 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/47.5 kB 122.9 kB/s eta 0:00:01
#    ---------------------------------------- 47.5/47.5 kB 140.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/377.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/377.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/377.6 kB ? eta -:--:--
# ...

# %%
#CODIGO FINAL 
#Librerias necesarias 
import cv2
from pyzbar.pyzbar import decode
from supabase import create_client, Client
from datetime import datetime

# Configurar Supabase
url: str = "https://rucchmdwalvfpsmdjawg.supabase.co"
key: str = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InJ1Y2NobWR3YWx2ZnBzbWRqYXdnIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjUwMzU1NDgsImV4cCI6MjA0MDYxMTU0OH0.qkaWcGeR-KqLe_UJS0uYfoPjxFfQXTLNB80vrGg_Tv0"
supabase: Client = create_client(url, key)

# Seleccionar la camara que se usa 
cap = cv2.VideoCapture(1)

# Variable para identificar el estacionamiento, ¿como se hara? de que tipo str o int
estacionamiento = "Estacionamiento 1" 

# Función para obtener la hora y fecha actual donde se ve 
def infhora():
    inf = datetime.now()
    fecha = inf.strftime('%Y-%m-%d')
    hora = inf.strftime('%H-%M-%S')
    return hora, fecha

# Lectura de QR
try:
    while True:
        ret, frame = cap.read()

        if not ret:
            print("No se puede capturar el frame de la cámara")
            break

        for codes in decode(frame):
            codigo = codes.data.decode('utf-8')

            # Verificar si el código ya existe en la base de datos
            response = supabase.table("ubicación").select("*").eq("codigo_qr", codigo).execute()
            registros = response.data

            if len(registros) == 0:
                # Si no existe, se hace un nuevo registro
                supabase.table("ubicación").insert({
                    "codigo_qr": codigo,
                    "Estacionamiento": estacionamiento,
                    "fecha_registro": datetime.now().strftime('%Y-%m-%d %H:%M:%S')
                }).execute()
                print(f"Nuevo código registrado en {estacionamiento}: {codigo}")
            else:
                # Se revisa si ya existe dentro del mismo estacionamiento
                registro = registros[0]
                if registro["Estacionamiento"] != estacionamiento:
                    print(f"El código {codigo} ya está registrado en {registro['Estacionamiento']}")

        # Se muestra la ventana de la camara 
        cv2.imshow("Lectura de codigo QR", frame)

        # Salir del ciclo con tecla ESC
        if cv2.waitKey(1) == 27:  # ESC para salir
            break

except Exception as e:
    print(f"Ocurrió un error: {e}")

finally:
  
    cap.release()
    cv2.destroyAllWindows()
# Out:
# Nuevo código registrado en Estacionamiento 1: 655717
# Nuevo código registrado en Estacionamiento 1: 655719
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 35
#      32     print("No se puede capturar el frame de la cámara")
#      33     break
# ---> 35 for codes in decode(frame):
#      36     codigo = codes.data.decode('utf-8')
#      38     # Verificar si el código ya existe en la base de datos
#
# File c:\Users\Aze_g\Downloads\anaconda\Lib\site-packages\pyzbar\pyzbar.py:230, in decode(image, symbols)
#     228 zbar_image_set_size(img, width, height)
#     229 zbar_image_set_data(img, cast(pixels, c_void_p), len(pixels), None)
# --> 230 decoded = zbar_scan_image(scanner, img)
#     231 if decoded < 0:
#     232     raise PyZbarError('Unsupported image format')
#
# KeyboardInterrupt:

# %%
# Liberar recursos
cap.release()
cv2.destroyAllWindows()
